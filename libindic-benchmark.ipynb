# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
kannada = pd.read_csv("/home/ixaxaar/src/telperion-test/names_5k.xlsx - Kannada.csv")
kannada
# Out:
#                       English                Kannada     Lang  \
# 0                     Surekha                 ಸುರೇಖಾ  kannada
# 1                      Surana                 ಸುರಾನಾ  kannada
# 2                      suresh                 ಸುರೇಶ್  kannada
# 3                       Kumar                ಕುಮಾರ್‌  kannada
# 4                       Suraj                  ಸೂರಜ್  kannada
# 5                       Surya                  ಸೂರ್ಯ  kannada
# 6                         Bab                   ಬಾಬು  kannada
# 7                   Surendran            ಸುರೇಂದ್ರನ್‌  kannada
# 8                         Rao                   ರಾವ್  kannada
# 9                       Hosur                 ಹೂಸೂರು  kannada
# 10                      Suran                 ಸುರಾನ್  kannada
# 11                    Surayya                 ಸೂರಯ್ಯ  kannada
# 12                 Suryakanth             ಸೂರ್ಯಕಾಂತ್  kannada
# 13                    Surappa                 ಸೂರಪ್ಪ  kannada
# ...

# %%
libindic_matches = 100 * len(kannada[ kannada['Kannada'] == kannada['Libindic'] ]) / len(kannada)
libindic_ml_matches = 100 * len(kannada[ kannada['Kannada'] == kannada['libindic-ml'] ]) / len(kannada)
reverie_matches = 100 * len(kannada[ kannada['Kannada'] == kannada['Reverie Output'] ]) / len(kannada)
print(libindic_matches)
print(libindic_ml_matches)
print(reverie_matches)
# Out:
# 11.547256097560975
# 11.547256097560975
# 49.84756097560975

# %%
hindi = pd.read_csv("/home/ixaxaar/src/telperion-test/names_5k.xlsx - Hindi.csv")
hindi
# Out:
#              Names    Parallel   Lang Reverie Output          Hit Status  \
# 0            kumar       कुमार  hindi          कुमार          NAMES_DICT
# 1             devi        देवी  hindi           देवी          NAMES_DICT
# 2            anita       अनिता  hindi          अनीता          NAMES_DICT
# 3             anil        अनिल  hindi           अनिल          NAMES_DICT
# 4             ajay         अजय  hindi            अजय          NAMES_DICT
# 5            singh        सिंह  hindi           सिंह           NAME_EXCP
# 6           ansari      अंसारी  hindi         अनसारी          NAMES_DICT
# 7             amit        अमित  hindi           अमित          NAMES_DICT
# 8            abdul      अब्दुल  hindi         अब्दुल          NAMES_DICT
# 9             ajit        अजीत  hindi           अजित          NAMES_DICT
# 10         khatoon       खातून  hindi          खातून          NAMES_DICT
# 11           anand       आनन्द  hindi          आनांद          NAMES_DICT
# ...

# %%
libindic_matches = 100 * len(hindi[ hindi['Parallel'] == hindi['Libindic'] ]) / len(hindi)
libindic_ml_matches = 100 * len(hindi[ hindi['Parallel'] == hindi['libindic-ml'] ]) / len(hindi)
reverie_matches = 100 * len(hindi[ hindi['Parallel'] == hindi['Reverie Output'] ]) / len(hindi)
print(libindic_matches)
print(libindic_ml_matches)
print(reverie_matches)
# Out:
# 40.15648128568408
# 40.15648128568408
# 45.65447240431381

# %%
bengali = pd.read_csv("/home/ixaxaar/src/telperion-test/names_5k.xlsx - Bengali.csv")
bengali
# Out:
#              English       Bengali     Lang Reverie Output  Hit Status Match  \
# 0             mahato         মাহাত  bengali            মহত  NAMES_DICT    No
# 1              kumar         কুমার  bengali          কুমার  NAMES_DICT   Yes
# 2                das           দাস  bengali            দাস  NAMES_DICT   Yes
# 3             mondal         মন্ডল  bengali          মণ্ডল  NAMES_DICT    No
# 4              bauri         বাউরি  bengali           বৌরী  NAMES_EXCP    No
# 5              molla        মোল্যা  bengali         মোল্লা  NAMES_DICT    No
# 6               sekh           সেখ  bengali            সেখ  NAMES_DICT   Yes
# 7             sardar      সর্দ্দার  bengali         সর্দার  NAMES_DICT    No
# 8             mandal         মণ্ডল  bengali          মণ্ডল  NAMES_DICT   Yes
# 9               bibi          বিবি  bengali           বিবি  NAMES_DICT   Yes
# 10             ghosh           ঘোষ  bengali            ঘোষ  NAMES_DICT   Yes
# ...

# %%
# libindic_matches = 100 * len(bengali[ bengali['Bengali'] == bengali['Libindic'] ]) / len(bengali)
libindic_ml_matches = 100 * len(bengali[ bengali['Bengali'] == bengali['libindic-ml'] ]) / len(bengali)
reverie_matches = 100 * len(bengali[ bengali['Bengali'] == bengali['Reverie Output'] ]) / len(bengali)
# print(libindic_matches)
print(libindic_ml_matches)
print(reverie_matches)
# Out:
# 35.85
# 75.23
